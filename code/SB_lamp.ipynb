# %%
import numpy as np
import matplotlib.pyplot as plt


data = np.loadtxt('SB_lamp.csv', delimiter=',', dtype=float, skiprows=1)

mV = [k[2] for k in data]
T = [k[3] for k in data]
I = [1.5e-13*k[3]**4 for k in data]

plt.plot(T, mV)
plt.plot(T, I)
plt.show()
